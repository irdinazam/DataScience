# %%
# Working with Missing Data in Pandas
# Missing Data can occur when no information is provided for one or more
# items or for a whole unit. Missing Data is a very big problem in a real-life scenarios.
# Missing Data can also refer to as NA(Not Available) values in pandas.
# In DataFrame sometimes many datasets simply arrive with missing data,
# either because it exists and was not collected or it never existed.
# For Example, Suppose different users being surveyed may choose not to share their income,
# some users may choose not to share the address in this way many datasets went missing.

# Dataset : https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/ufo.csv

# %%
import pandas as pd

# %%
ufo = pd.read_csv('https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/ufo.csv')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18215 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
# check missing value
ufo.isnull().sum()
# Out:
# City                  26
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
# Handle missing values     (can be use if small numbers of missing values | 50-60 rows )
# inplace = True (will change only if this code is written)
ufo.dropna().shape
# ufo.dropna(inplace = True)
# Out:
# (2486, 5)

# %%
# fillna()
# Fill NA or NaN values
# to make it permanent add inplace=True
ufo['City'].fillna(value='CityNotKnown',inplace = True)

# %%
ufo['City'].value_counts().head(60)
# Out:
# City
# Seattle             187
# New York City       161
# Phoenix             137
# Houston             108
# Las Vegas           105
# Portland            102
# San Diego           101
# Los Angeles          98
# Chicago              73
# Austin               62
# Miami                60
# Tucson               58
# Columbus             55
# Albuquerque          54
# Dallas               52
# Tacoma               52
# St. Louis            51
# San Francisco        51
# Spokane              49
# Auburn               48
# Jacksonville         48
# Salem                48
# Sacramento           46
# Salt Lake City       46
# Gilbert              45
# Denver               44
# Colorado Springs     44
# Springfield          43
# San Antonio          43
# Cleveland            42
# Reno                 42
# San Jose             42
# Atlanta              40
# Pittsburgh           40
# Kansas City          38
# Rockford             38
# Orlando              37
# Louisville           37
# Arlington            36
# Columbia             35
# Scottsdale           35
# Tampa                34
# Bellevue             34
# Indianapolis         34
# Memphis              34
# Vancouver            34
# Bakersfield          33
# Albany               32
# Rochester            31
# Jackson              31
# Glendale             30
# Redding              30
# Philadelphia         30
# Chandler             30
# Omaha                30
# Madison              29
# Kent                 28
# Greenville           28
# Richmond             28
# Mesa                 28
# Name: count, dtype: int64

# %%
ufo['Colors Reported'].value_counts()
# do not show missing values
# Out:
# Colors Reported
# RED                       780
# GREEN                     531
# ORANGE                    528
# BLUE                      450
# YELLOW                    169
# RED GREEN                  89
# RED BLUE                   78
# RED ORANGE                 44
# GREEN BLUE                 34
# RED GREEN BLUE             33
# ORANGE YELLOW              26
# RED YELLOW                 25
# ORANGE GREEN               23
# YELLOW GREEN               17
# ORANGE BLUE                10
# RED YELLOW GREEN            9
# YELLOW BLUE                 6
# YELLOW GREEN BLUE           5
# ORANGE GREEN BLUE           5
# RED ORANGE YELLOW           4
# RED YELLOW GREEN BLUE       4
# RED YELLOW BLUE             3
# RED ORANGE GREEN            3
# RED ORANGE BLUE             3
# RED ORANGE YELLOW BLUE      1
# ORANGE YELLOW GREEN         1
# ORANGE YELLOW BLUE          1
# Name: count, dtype: int64

# %%
ufo['Colors Reported'].fillna(value='ColorsNotKnown',inplace = True)
# Out:
# /tmp/ipython-input-4232923695.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ufo['Colors Reported'].fillna(value='ColorsNotKnown',inplace = True)

# %%
ufo['Shape Reported'].fillna(value='ShapeNotKnown',inplace = True)
# Out:
# /tmp/ipython-input-363525594.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ufo['Shape Reported'].fillna(value='ShapeNotKnown',inplace = True)

# %%
ufo.isnull().sum()
# Out:
# City               0
# Colors Reported    0
# Shape Reported     0
# State              0
# Time               0
# dtype: int64

# %%
# Load the Dataset
data = pd.read_csv('https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/sample11.csv')
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0         NaN
# 2   3  Alex    NaN        67.0
# 3   4  Alex   12.0         NaN
# 4   5  Alex    NaN         NaN
# 5   6  Alex   54.0         NaN
# 6   7  Alex   65.0        66.0

# %%
data.isnull().sum()
# Out:
# Id            0
# Name          0
# Marks         2
# Percentage    4
# dtype: int64

# %%
# fillna()
# method --> ffill   [forward fill]

data['Marks'].fillna(method='ffill',inplace=True)
# Out:
# /tmp/ipython-input-3302738698.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Marks'].fillna(method='ffill',inplace=True)
# /tmp/ipython-input-3302738698.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Marks'].fillna(method='ffill',inplace=True)

# %%
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0         NaN
# 2   3  Alex   23.0        67.0
# 3   4  Alex   12.0         NaN
# 4   5  Alex   12.0         NaN
# 5   6  Alex   54.0         NaN
# 6   7  Alex   65.0        66.0

# %%
# method --> bfill   [backward fill]

data['Percentage'].fillna(method='bfill',inplace=True)
# Out:
# /tmp/ipython-input-2382014135.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Percentage'].fillna(method='bfill',inplace=True)
# /tmp/ipython-input-2382014135.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Percentage'].fillna(method='bfill',inplace=True)

# %%
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0        67.0
# 2   3  Alex   23.0        67.0
# 3   4  Alex   12.0        66.0
# 4   5  Alex   12.0        66.0
# 5   6  Alex   54.0        66.0
# 6   7  Alex   65.0        66.0

# %%
# Load the Dataset
data = pd.read_csv('https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/sample11.csv')
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0         NaN
# 2   3  Alex    NaN        67.0
# 3   4  Alex   12.0         NaN
# 4   5  Alex    NaN         NaN
# 5   6  Alex   54.0         NaN
# 6   7  Alex   65.0        66.0

# %%
# Fill missing values by taking up a mean
mean_val = data['Percentage'].mean()
mean_val = round(mean_val,1)
mean_val
data['Percentage'].fillna(value=mean_val,inplace=True)
# Out:
# /tmp/ipython-input-3487826481.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Percentage'].fillna(value=mean_val,inplace=True)

# %%
mean_val2 = data['Marks'].mean()
mean_val2 = round(mean_val,1)
mean_val2
data['Marks'].fillna(value=mean_val2,inplace=True)
# Out:
# /tmp/ipython-input-1963352648.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Marks'].fillna(value=mean_val2,inplace=True)

# %%
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0        70.3
# 2   3  Alex   70.3        67.0
# 3   4  Alex   12.0        70.3
# 4   5  Alex   70.3        70.3
# 5   6  Alex   54.0        70.3
# 6   7  Alex   65.0        66.0

# %%
# Load the Dataset
data = pd.read_csv('https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/sample11.csv')
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0         NaN
# 2   3  Alex    NaN        67.0
# 3   4  Alex   12.0         NaN
# 4   5  Alex    NaN         NaN
# 5   6  Alex   54.0         NaN
# 6   7  Alex   65.0        66.0

# %%
# interpolate()
'''
Python Pandas interpolate() method is used to fill NaN values in the DataFrame
or Series using various interpolation techniques to fill the missing values
rather than hard-coding the value.
Interpolation in Python is a technique used to estimate unknown data points
between two known data points.
'''

data.interpolate()
# Out:
# /tmp/ipython-input-85168374.py:10: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data.interpolate()
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0       78.00
# 1   2  Alex   23.0       72.50
# 2   3  Alex   17.5       67.00
# 3   4  Alex   12.0       66.75
# 4   5  Alex   33.0       66.50
# 5   6  Alex   54.0       66.25
# 6   7  Alex   65.0       66.00

# %%
# Dealing With Duplicate Data
# Create a DataFrame
data = {
      'StudentName': ['Mark', 'Ali', 'Bob', 'John', 'Johny', 'Mark'],
      'Score': [45, 65, 76, 44, 39, 45]
}
df = pd.DataFrame(data)
df
# Out:
#   StudentName  Score
# 0        Mark     45
# 1         Ali     65
# 2         Bob     76
# 3        John     44
# 4       Johny     39
# 5        Mark     45

# %%
# dropping duplicates
df.drop_duplicates()
# Out:
#   StudentName  Score
# 0        Mark     45
# 1         Ali     65
# 2         Bob     76
# 3        John     44
# 4       Johny     39

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#   StudentName  Score
# 0        Mark     45
# 1         Ali     65
# 2         Bob     76
# 3        John     44
# 4       Johny     39

# %%
data = {
      'StudentName': ['Mark', 'Ali', 'Bob', 'John', 'Johny', 'Mark'],
      'Score': [45, 65, 76, 44, 39, 45]
}
df = pd.DataFrame(data)
df
# Out:
#   StudentName  Score
# 0        Mark     45
# 1         Ali     65
# 2         Bob     76
# 3        John     44
# 4       Johny     39
# 5        Mark     45

# %%
df.drop_duplicates(keep='last',inplace=True)

# %%
df
# Out:
#   StudentName  Score
# 1         Ali     65
# 2         Bob     76
# 3        John     44
# 4       Johny     39
# 5        Mark     45
